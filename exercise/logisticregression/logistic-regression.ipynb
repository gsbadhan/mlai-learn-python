# %%
import pandas as pd
import matplotlib.pyplot as plot
# %matplotlib inline
import sklearn.linear_model as model
import seaborn as sbn

# %%
hs=pd.read_csv("datasets/age-house-owned.csv")
hs.head(5)
# Out:
#    age  house
# 0    1      0
# 1    2      0
# 2    3      0
# 3    4      0
# 4    5      0

# %%
hs.hist(figsize=(5,3))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'house'}>]], dtype=object)

# %%
sbn.pairplot(hs,diag_kind = "kde")

# %%
plot.scatter(hs["age"],hs["house"],marker="+")

# %%
X=hs[["age"]]
y=hs["house"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df.head(5)
# Out:
#     Actual  Predicted
# 10       0          0
# 74       1          1
# 66       1          1
# 51       1          1
# 7        0          0

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[9.86588649e-01, 1.34113513e-02],
#        [4.31039361e-05, 9.99956896e-01],
#        [2.59083114e-04, 9.99740917e-01],
#        [7.42964262e-03, 9.92570357e-01],
#        [9.93110259e-01, 6.88974102e-03],
#        [1.75800465e-05, 9.99982420e-01],
#        [7.61639292e-07, 9.99999238e-01],
#        [1.19262292e-06, 9.99998807e-01],
#        [2.63690618e-08, 9.99999974e-01],
#        [6.35014679e-04, 9.99364985e-01],
#        [4.53577882e-01, 5.46422118e-01],
#        [9.97743998e-01, 2.25600241e-03],
#        [4.86402124e-07, 9.99999514e-01],
#        [8.33067594e-01, 1.66932406e-01],
#        [4.30631593e-02, 9.56936841e-01],
#        [4.57892651e-06, 9.99995421e-01],
#        [7.61166989e-01, 2.38833011e-01],
#        [5.39373026e-05, 9.99946063e-01],
#        [9.93989358e-04, 9.99006011e-01],
#        [2.43367963e-03, 9.97566320e-01],
#        [9.50397485e-01, 4.96025150e-02],
#        [9.74055161e-01, 2.59448386e-02],
#        [6.70544882e-01, 3.29455118e-01],
#        [2.92422236e-06, 9.99997076e-01]])

# %%
from sklearn import metrics
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[ 8,  0],
#        [ 0, 16]])

# %%
predict=model.predict([[25]])
predict
# Out:
# array([0])

# %%
predict=model.predict([[31]])
predict
# Out:
# array([1])
